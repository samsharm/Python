# %% [markdown]
# <a href="https://colab.research.google.com/github/samsharm/Python/blob/master/Capstone1CDC1005_Samta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install MySQL-Connector
# Out:
# ...
#      |████████████████████████████████| 11.9MB 5.8MB/s
# ...
#   Created wheel for MySQL-Connector: filename=mysql_connector-2.2.9-cp37-cp37m-linux_x86_64.whl size=247949 sha256=55662c69dd5454f99ca1e3e73c17330a19868b9e5c1f0e1faffa20154515a69f
#   Stored in directory: /root/.cache/pip/wheels/8c/83/a1/f8b6d4bb1bd6208bbde1608bbfa7557504bed9eaf2ecf8c175
# Successfully built MySQL-Connector
# ...

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="cpanel.insaid.co",
  user="student",
  password="student",
  database='Capstone1'
)

print(mydb)

# %%
mycursor = mydb.cursor(buffered=True)

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('Capstone1',)
# ('Capstone2',)
# ('Capstone3',)

# %%
mycursor.execute("USE Capstone1")

# %%
mycursor.execute("SHOW TABLES")

# %%
query = "SELECT * FROM gender_age_train"

mycursor.execute(query)

# %%
result = mycursor.fetchall()
for row in result:
  print(row)
# Out:
# Streaming output truncated to the last 5000 lines.
# (-5332955854743680542, 'M', 21, 'M22-')
# (-5519955118588979650, 'M', 22, 'M22-')
# (8717415794854785323, 'M', 20, 'M22-')
# (388907664759658514, 'M', 25, 'M23-26')
# (-9031158305892744705, 'M', 26, 'M23-26')
# (1554590942599044135, 'M', 30, 'M29-31')
# (1651855091981574886, 'M', 26, 'M23-26')
# (-340273132767975897, 'M', 37, 'M32-38')
# (-8753233223531327930, 'M', 33, 'M32-38')
# (-791905761469668502, 'M', 33, 'M32-38')
# (3079552414843841522, 'M', 27, 'M27-28')
# (-1701982466574937578, 'M', 27, 'M27-28')
# (-3398786563816067750, 'F', 44, 'F43+')
# (-3736448788161836201, 'F', 30, 'F29-32')
# (6959154714020164540, 'M', 42, 'M39+')
# (-7799679327277570563, 'M', 33, 'M32-38')
# (-3689584701868520712, 'F', 53, 'F43+')
# (-8114418839212865047, 'F', 53, 'F43+')
# (1946365843766433256, 'M', 35, 'M32-38')
# (-2880222370084408958, 'M', 37, 'M32-38')
# (6294125561774404003, 'M', 26, 'M23-26')
# (8599125069808664368, 'M', 26, 'M23-26')
# ...

# %%
query2 = "SELECT * FROM phone_brand_device_model"

mycursor.execute(query2)

# %%
result = mycursor.fetchall()
for row in result:
  print(row)
# Out:
# Streaming output truncated to the last 5000 lines.
# (2629563526833001857, '魅族', 'MX4 Pro')
# (7362313985107003539, '魅族', 'MX4 Pro')
# (-2344134889506009194, 'OPPO', 'R2010')
# (8727468779481290181, '三星', 'Galaxy Grand 2')
# (-2558053407381293870, 'vivo', 'X3L')
# (-885670780472164025, '小米', 'MI 2')
# (-7467946873574376549, '三星', 'A670t')
# (5624256271437120641, 'HTC', 'One')
# (-4335333182841518358, '小米', 'MI 4')
# (6536349942980514930, '小米', 'MI 3')
# (-1204512430719063247, '酷派', 'Y80D')
# (3955134778801994295, '三星', 'Galaxy Note 3')
# (-3503019268977820403, 'OPPO', 'R809T')
# (5499494991694692861, '华为', '荣耀6 plus')
# (808721550679555973, 'vivo', 'X3V')
# (6805622730280979221, '酷派', 'Y1')
# (3850320763555751047, '小米', '红米note')
# (5850457261146004638, '华为', '荣耀+')
# (-4713997808455134096, '小米', 'MI 2S')
# (-1561592761213017201, '三星', 'Galaxy S4')
# (5386314439349152758, '小米', '红米note')
# (8265647007278529961, '小米', 'MI 2A')
# (2428933289821523693, 'vivo', 'Xperia C')
# ...
