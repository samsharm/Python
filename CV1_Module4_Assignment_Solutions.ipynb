# %% [markdown]
# <img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240" height="360" />

# %% [markdown]
# # Computer Vision - I Module 4 Assignment

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/insaid2018/DeepLearning/master/Data/cat_dog_panda.csv')
df.head()
# Out:
#    pixel1  pixel2  pixel3  pixel4  ...  pixel4094  pixel4095  pixel4096  label
# 0     195     196     198     200  ...        170        170        165      1
# 1      10       7       4       3  ...        133        139        155      1
# 2     202     194     204     193  ...         76         73         88      2
# 3     111     129     167      91  ...         90        126        107      2
# 4      92      84      86      80  ...          4          5          5      1
#
# [5 rows x 4097 columns]

# %%
print(df.shape)
ntrain = df.shape[0]
# Out:
# (3000, 4097)

# %% [markdown]
# ### Data Description:
#
# This dataset consists of 3000 images of cats, dogs, and pandas.
# Each class has a 1000 images and each image is labelled according to the class it belongs.
#
#
# | Number of Samples | Animal | Label |
# | :---: | :---: | :---: |
# | 1000 samples |  cat | 1 |
# | 1000 samples |  dog | 2 |
# | 1000 samples |  panda | 3 |

# %% [markdown]
# ### Question 1: Extract X and y from the dataframe **df**.
#
# - **X** should contain all the columns containing pixel values.
#
# - **y** should contain the column *label*.

# %%
def extract_x(df):
    X = df.drop("label", axis=1)

    return X

# %%
X = extract_x(df)
X.head()
# Out:
#    pixel1  pixel2  pixel3  pixel4  ...  pixel4093  pixel4094  pixel4095  pixel4096
# 0     195     196     198     200  ...        166        170        170        165
# 1      10       7       4       3  ...        139        133        139        155
# 2     202     194     204     193  ...         62         76         73         88
# 3     111     129     167      91  ...         67         90        126        107
# 4      92      84      86      80  ...          3          4          5          5
#
# [5 rows x 4096 columns]

# %%
# The images are in square from, so dim*dim = 1024
from math import sqrt
dim = int(sqrt(X.shape[1]))
print("The images are {}x{} square.".format(dim, dim))
# Out:
# The images are 64x64 square.

# %%
print("Shape of X: ", X.shape)
# Out:
# Shape of X:  (3000, 4096)

# %%
def extract_y(df):
    y = df['label']

    return y

# %%
y = extract_y(df)
y.head()
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    1
# Name: label, dtype: int64

# %%
print("Shape of y: ", y.shape)
# Out:
# Shape of y:  (3000,)

# %% [markdown]
# ### Question 2: Convert X to (num_images, img_rows, img_cols) shape.
#
# - Use **ntrain** as **num_images**.
#
# - Use **dim** as **img_rows**, and **img_cols**.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
def reshape_X(X):
    X_vis = X.values.reshape(ntrain, dim, dim)

    return X_vis

# %%
X_vis = reshape_X(X)

# %%
for i in range(1, 4):                                            # Specifying how many images to show in the 3x3 grid
    plt.subplot(1, 3, i)                                         # Open next subplot
    plt.imshow(X_vis[i], cmap=plt.get_cmap('gray'))
    plt.title(y[i]);

# %% [markdown]
# ### Question 3: Perform Normalization of the pixel values.
#
# - All values should lie between 0 and 1 after normalization.

# %%
def normalize_X(X):
    X = X / 255.0

    return X

# %%
X = normalize_X(X)

# %%
X.head()
# Out:
#      pixel1    pixel2    pixel3  ...  pixel4094  pixel4095  pixel4096
# 0  0.764706  0.768627  0.776471  ...   0.666667   0.666667   0.647059
# 1  0.039216  0.027451  0.015686  ...   0.521569   0.545098   0.607843
# 2  0.792157  0.760784  0.800000  ...   0.298039   0.286275   0.345098
# 3  0.435294  0.505882  0.654902  ...   0.352941   0.494118   0.419608
# 4  0.360784  0.329412  0.337255  ...   0.015686   0.019608   0.019608
#
# [5 rows x 4096 columns]

# %% [markdown]
# ### Question 4: Reshape image data to (nimg, img_rows, img_cols, 1) shape.
#
# - Use **ntrain** as **nimg**.
#
# - Use **dim** as **img_rows**, and **img_cols**.

# %%
print("Previous shape, pixels are in 1D vector:", X.shape)
# Out:
# Previous shape, pixels are in 1D vector: (3000, 4096)

# %%
def reshape_X_4d(X):
    X = X.values.reshape(ntrain, dim, dim, 1)
    
    return X

# %%
X = reshape_X_4d(X)

# %%
print("After reshape, pixels are a 64x64x1 3D matrix:", X.shape)
# Out:
# After reshape, pixels are a 64x64x1 3D matrix: (3000, 64, 64, 1)

# %% [markdown]
# ### Question 5: Perform One Hot Encoding or Dummy Encoding of label **y**.
#
# - Use **pd.get_dummies()** to perform this process.

# %%
print(type(y))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print("Shape of y before: ", y.shape)
# Out:
# Shape of y before:  (3000,)

# %%
def ohe_y(y):
    y = pd.get_dummies(y)

    return y

# %%
y = ohe_y(y)

# %%
print("Shape of y after: ", y.shape)
print(type(y))
# Out:
# Shape of y after:  (3000, 3)
# <class 'pandas.core.frame.DataFrame'>

# %%
y = y.values
type(y)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Question 6: Split the dataset into training and validation sets.
#
# - Use **test_size** = **split_pct**
#
# - Use **random_state** = **seed**

# %%
from sklearn.model_selection import train_test_split

# %%
# fixing random seed for reproducibility
seed = 142

# %%
# percentage of X which will be xval
split_pct = 0.1

# %%
def train_val_split(X, y, seed, split_pct):
    xtrain, xval, ytrain, yval = train_test_split(X, y, test_size=split_pct, random_state=seed)

    return xtrain, xval, ytrain, yval

# %%
xtrain, xval, ytrain, yval = train_val_split(X, y, seed, split_pct)

# %%
print(xtrain.shape, ytrain.shape, xval.shape, yval.shape)
# Out:
# (2700, 64, 64, 1) (2700, 3) (300, 64, 64, 1) (300, 3)

# %% [markdown]
# ## CNN Model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPool2D

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# ### Question 7: Define Model Architecture
#
# - Specify **input_shape=(dim,dim,1)** in 1st layer.
#
# - Specify **nclasses** as the number of hidden units in the last layer of the model with appropriate activation function.

# %%
dim = 64
nclasses = 3

# %%
def build_model(dim, nclasses):
    model = Sequential()
    model.add(Conv2D(filters=32, kernel_size=(5,5), padding='same', activation='relu', input_shape=(dim, dim, 1)))
    model.add(Conv2D(filters=32, kernel_size=(5,5), padding='same', activation='relu',))
    model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(filters=64, kernel_size=(5,5), padding='same', activation='relu'))
    model.add(Conv2D(filters=64, kernel_size=(5,5), padding='same', activation='relu'))
    model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
    model.add(Dropout(0.2))

    model.add(Flatten())
    model.add(Dense(120, activation='relu'))
    model.add(Dense(84, activation='relu'))
    model.add(Dense(nclasses, activation='softmax'))

    return model

# %%
model = build_model(dim, nclasses)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        832
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        25632
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        51264
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 64)        102464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               1966200
# _________________________________________________________________
# dense_2 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 255
# =================================================================
# Total params: 2,156,811
# Trainable params: 2,156,811
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Question 8: Compile the model
#
# - Use **adam** as the **optimizer**.
#
# - Use **accuracy** as the **metrics**.

# %%
def compile_model(model):
    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

    return model

# %%
model = compile_model(model)

# %% [markdown]
# ### Question 9: Create a Learning Rate Annealer
#
# - It should monitor **val_acc**.
#
# - It should have **patience=3**, **factor=0.5**, and **min_lr=0.00001**.

# %%
def lr_annealer():
    lr_reduction = ReduceLROnPlateau(monitor='val_acc', patience=3, verbose=1, factor=0.5, min_lr=0.00001)

    return lr_reduction

# %%
lr_reduction = lr_annealer()

# %% [markdown]
# ### Data Augmentation
#
# - The process of Data Augmentation will be taught in-depth in Computer Vision - II.

# %%
datagen = ImageDataGenerator(
          featurewise_center=False,            # set input mean to 0 over the dataset
          samplewise_center=False,             # set each sample mean to 0
          featurewise_std_normalization=False, # divide inputs by std of the dataset
          samplewise_std_normalization=False,  # divide each input by its std
          zca_whitening=False,                 # apply ZCA whitening
          rotation_range=30,                   # randomly rotate images in the range (degrees, 0 to 180)
          zoom_range = 0.1,                    # Randomly zoom image 
          width_shift_range=0.1,               # randomly shift images horizontally (fraction of total width)
          height_shift_range=0.1,              # randomly shift images vertically (fraction of total height)
          horizontal_flip=False,               # randomly flip images horizontally
          vertical_flip=False                  # randomly flip images vertically
          )

# %%
datagen.fit(X)

# %% [markdown]
# ### Question 10: Fit the model
#
# - Use **fit_generator** for fitting the model with the training data **xtrain**, **ytrain** and **batch_size** inside **datagen.flow**
#
# - Use **epochs=epochs**.
#
# - Specify **xval, yval** as the **validation_data**.
#
# - Also, specify the **lr_reduction** as the callback.
#
# - Properly compute the **steps_per_epoch** using the **batch_size**.

# %%
epochs = 100
batch_size = 64

# %%
def fit_model(model, epochs, batch_size):
    history = model.fit_generator(datagen.flow(xtrain, ytrain, batch_size=batch_size),
                                epochs=epochs, 
                                validation_data=(xval, yval),
                                verbose=1, 
                                steps_per_epoch=xtrain.shape[0] // batch_size, 
                                callbacks=[lr_reduction])  
    
    return model, history

# %%
model, history = fit_model(model, epochs, batch_size)
# Out:
# 42/42 [==============================] - 5s 123ms/step - loss: 0.9564 - acc: 0.4939 - val_loss: 0.8142 - val_acc: 0.5533
# Epoch 2/100
# 42/42 [==============================] - 2s 47ms/step - loss: 0.8105 - acc: 0.5830 - val_loss: 0.8207 - val_acc: 0.5967
# Epoch 3/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.7740 - acc: 0.5981 - val_loss: 0.7940 - val_acc: 0.5467
# Epoch 4/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.7450 - acc: 0.6268 - val_loss: 0.7052 - val_acc: 0.6867
# Epoch 5/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.7345 - acc: 0.6278 - val_loss: 0.8072 - val_acc: 0.6100
# Epoch 6/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.7258 - acc: 0.6465 - val_loss: 0.7321 - val_acc: 0.6633
# Epoch 7/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.6987 - acc: 0.6544 - val_loss: 0.6820 - val_acc: 0.6633
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 8/100
# 42/42 [==============================] - 2s 46ms/step - loss: 0.6609 - acc: 0.6756 - val_loss: 0.6968 - val_acc: 0.6100
# Epoch 9/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.6548 - acc: 0.6691 - val_loss: 0.7082 - val_acc: 0.6467
# Epoch 10/100
# 42/42 [==============================] - 2s 49ms/step - loss: 0.6314 - acc: 0.6931 - val_loss: 0.7337 - val_acc: 0.6267
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 11/100
# 42/42 [==============================] - 2s 46ms/step - loss: 0.6376 - acc: 0.6881 - val_loss: 0.7266 - val_acc: 0.6367
# Epoch 12/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.6158 - acc: 0.7005 - val_loss: 0.6818 - val_acc: 0.6533
# Epoch 13/100
# 42/42 [==============================] - 2s 47ms/step - loss: 0.5811 - acc: 0.7190 - val_loss: 0.6591 - val_acc: 0.6633
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 14/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5645 - acc: 0.7356 - val_loss: 0.7418 - val_acc: 0.6700
# Epoch 15/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5947 - acc: 0.7144 - val_loss: 0.7398 - val_acc: 0.6467
# Epoch 16/100
# 42/42 [==============================] - 2s 50ms/step - loss: 0.5924 - acc: 0.7281 - val_loss: 0.7607 - val_acc: 0.6567
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 17/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5632 - acc: 0.7296 - val_loss: 0.7238 - val_acc: 0.6633
# Epoch 18/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5665 - acc: 0.7353 - val_loss: 0.7088 - val_acc: 0.6633
# Epoch 19/100
# 42/42 [==============================] - 2s 49ms/step - loss: 0.5520 - acc: 0.7396 - val_loss: 0.7015 - val_acc: 0.6733
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 20/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5589 - acc: 0.7214 - val_loss: 0.7338 - val_acc: 0.6833
# Epoch 21/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.
100
# 42/42 [==============================] - 2s 47ms/step - loss: 0.5278 - acc: 0.7538 - val_loss: 0.7233 - val_acc: 0.6800
# Epoch 86/100
# 42/42 [==============================] - 2s 46ms/step - loss: 0.5178 - acc: 0.7622 - val_loss: 0.7214 - val_acc: 0.6900
# Epoch 87/100
# 42/42 [==============================] - 2s 46ms/step - loss: 0.5288 - acc: 0.7550 - val_loss: 0.7288 - val_acc: 0.6833
# Epoch 88/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5171 - acc: 0.7611 - val_loss: 0.7248 - val_acc: 0.6933
# Epoch 89/100
# 42/42 [==============================] - 2s 47ms/step - loss: 0.5272 - acc: 0.7590 - val_loss: 0.7355 - val_acc: 0.6867
# Epoch 90/100
# 42/42 [==============================] - 2s 49ms/step - loss: 0.5189 - acc: 0.7668 - val_loss: 0.7254 - val_acc: 0.6933
# Epoch 91/100
# 42/42 [==============================] - 2s 49ms/step - loss: 0.5163 - acc: 0.7570 - val_loss: 0.7174 - val_acc: 0.6967
# Epoch 92/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5242 - acc: 0.7619 - val_loss: 0.7332 - val_acc: 0.6833
# Epoch 93/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5140 - acc: 0.7624 - val_loss: 0.7253 - val_acc: 0.7000
# Epoch 94/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5406 - acc: 0.7542 - val_loss: 0.7094 - val_acc: 0.6967
# Epoch 95/100
# 42/42 [==============================] - 2s 50ms/step - loss: 0.5164 - acc: 0.7690 - val_loss: 0.7293 - val_acc: 0.6867
# Epoch 96/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5147 - acc: 0.7586 - val_loss: 0.7468 - val_acc: 0.6733
# Epoch 97/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5193 - acc: 0.7670 - val_loss: 0.7176 - val_acc: 0.6933
# Epoch 98/100
# 42/42 [==============================] - 2s 47ms/step - loss: 0.5116 - acc: 0.7645 - val_loss: 0.7447 - val_acc: 0.6700
# Epoch 99/100
# 42/42 [==============================] - 2s 48ms/step - loss: 0.5358 - acc: 0.7560 - val_loss: 0.7507 - val_acc: 0.6667
# Epoch 100/100
# 42/42 [==============================] - 2s 47ms/step - loss: 0.5121 - acc: 0.7651 - val_loss: 0.7329 - val_acc: 0.6800

# %% [markdown]
# ### Plotting Loss and Accuracy

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="Validation loss",axes =ax[0])
ax[0].grid(color='black', linestyle='-', linewidth=0.25)
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['acc'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_acc'], color='r',label="Validation accuracy")
ax[1].grid(color='black', linestyle='-', linewidth=0.25)
legend = ax[1].legend(loc='best', shadow=True)

# %% [markdown]
# ### Plotting Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Predict the values from the validation dataset
ypred_onehot = model.predict(xval)

# %%
# Convert predictions classes from one hot vectors to labels: [0 0 1 0 0 ...] --> 2
ypred = np.argmax(ypred_onehot, axis=1)

# %%
# Convert validation observations from one hot vectors to labels
ytrue = np.argmax(yval, axis=1)

# %%
# Compute the confusion matrix
confusion_mtx = confusion_matrix(ytrue, ypred)

# %%
# Plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes=range(nclasses))

# %% [markdown]
# ### Plot Errors

# %%
errors = (ypred - ytrue != 0)

# %%
ypred_er = ypred_onehot[errors]
ypred_classes_er = ypred[errors]
ytrue_er = ytrue[errors]
xval_er = xval[errors]

# %%
def display_errors(errors_index, img_errors, pred_errors, obs_errors):
    """ This function shows 6 images with their predicted and real labels"""
    n = 0
    nrows = 2
    ncols = 3
    fig, ax = plt.subplots(nrows, ncols, sharex=True, sharey=True)
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row,col].imshow((img_errors[error]).reshape((64, 64)), cmap=plt.cm.gray)
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(pred_errors[error],obs_errors[error]))
            plt.subplots_adjust(bottom = 0.001)
            n += 1

# %%
# Probabilities of the wrong predicted numbers
ypred_er_prob = np.max(ypred_er,axis=1)

# %%
# Predicted probabilities of the true values in the error set
true_prob_er = np.diagonal(np.take(ypred_er, ytrue_er, axis=1))

# %%
# Difference between the probability of the predicted label and the true label
delta_pred_true_er = ypred_er_prob - true_prob_er

# %%
# Sorted list of the delta prob errors
sorted_delta_er = np.argsort(delta_pred_true_er)

# %%
# Top 6 errors. You can change the range to see other images
most_important_er = sorted_delta_er[-6:]

# %%
# Show the top 6 errors
display_errors(most_important_er, xval_er, ypred_classes_er, ytrue_er)
